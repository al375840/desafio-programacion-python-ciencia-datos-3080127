# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import normalize
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv('clientes.csv', delimiter=";")

# %%
print(df.head())
# Out:
#    Salario  Gasto
# 0     1500   0.08
# 1     1500   0.25
# 2     1600   0.11
# 3     1600   0.06
# 4     1700   0.21

# %%
dendrogram(linkage(df, method='ward',  metric='euclidean'))
plt.axhline(y=15000, color='r', linestyle='--')

# %%
agglomerative = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
agglomerative.fit(df)
labels = agglomerative.labels_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agglomerative = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
#       2 agglomerative.fit(df)
#       3 labels = agglomerative.labels_
#
# TypeError: __init__() got an unexpected keyword argument 'affinity'

# %%
print(labels)

# %%
plt.scatter(df['Salario'], df['Gasto'], c=labels) 
plt.xlabel('Salario Mensual')
plt.ylabel('Porcentaje Gasto Mensual')
